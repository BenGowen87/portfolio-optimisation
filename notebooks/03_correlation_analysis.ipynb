# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
from src.data_utils import get_returns_data

#get the returns data frame
returns_df = get_returns_data()

#prints the first few dates
print(returns_df.head())
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker          AAPL      MSFT      NVDA       SPY
# 2019-01-03 -0.099608 -0.036788 -0.060417 -0.023863
# 2019-01-04  0.042690  0.046509  0.064068  0.033496
# 2019-01-07 -0.002226  0.001276  0.052940  0.007885
# 2019-01-08  0.019063  0.007251 -0.024895  0.009395
# 2019-01-09  0.016982  0.014299  0.019667  0.004673

# %%
correlation_matrix = returns_df.corr()

print(correlation_matrix)
# Out:
# Ticker      AAPL      MSFT      NVDA       SPY
# Ticker
# AAPL    1.000000  0.758621  0.657635  0.804537
# MSFT    0.758621  1.000000  0.707202  0.824587
# NVDA    0.657635  0.707202  1.000000  0.712470
# SPY     0.804537  0.824587  0.712470  1.000000

# %% [markdown]
# This is the correlation matrix which represents the correlation between each pair of stocks. We notice that this matrix is symmetric as the correlation between Apple and Microsoft is the same as the correlation between Microsoft and Apple. Correlation is a result between -1 and 1 which measures the strength and direction of the relationship between 2 variables. A correlation coefficient of 1 means theres a perfect linear relationship between the 2 variables (if one increases the other increases by a predicatable amount). A correlation coefficient of 0 means there is no linear relationship between the 2 variables.
#
# From the correlation matrix you can see that the correlation between the S&P500 and the 3 companies is a strong positive linear relationship as the S&P500 reflects the general market performance. Additionally the correlation between Apple and Microsoft is a strong positive relationship as they are both large technology companies that are likely influenced by similar market conditions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# creating a heat map of the correlation matrix
plt.figure(figsize=(8,6))

sns.heatmap(correlation_matrix,
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# Correlation is important because investing in stocks with imperfect correlation can reduce portfolio risk. If all assets in a portfolio behave similarly, a decrease in one asset’s returns is likely to coincide with decreases in the others.
